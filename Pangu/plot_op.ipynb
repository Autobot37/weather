# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
prediction = np.load("/home/vatsal/NWM/Pangu/Pangu-Weather/output_data/output_surface.npy")

# %%
prediction.shape
# Out:
# (4, 721, 1440)

# %%
plt.imshow(prediction[0, :, :], cmap='jet')
plt.colorbar()

# %%
gt = np.load("/home/vatsal/NWM/Pangu/Pangu-Weather/input_data/input_surface.npy")

# %%
gt.shape
# Out:
# (4, 721, 1440)

# %%
plt.imshow(gt[0, :, :], cmap='jet')
plt.colorbar()

# %%
plt.imshow(prediction[1, :, :])
plt.colorbar()

# %%
plt.imshow(prediction[1, :, :])
plt.colorbar()

# %%
for i in range(0, 4):
    plt.imshow(prediction[i, :, :], cmap='jet')
    plt.colorbar(shrink=0.5)
    plt.show()

# %%
for i in range(0, 4):
    plt.imshow(gt[i, :, :], cmap='jet')
    plt.colorbar(shrink=0.5)
    plt.show()

# %%
prediction = np.load("/home/vatsal/NWM/Pangu/Pangu-Weather/output_data/output_upper_6hr.npy")

# %%
for i in range(0, 5):
    plt.imshow(gt[i,1, :, :], cmap='jet')
    plt.colorbar(shrink=0.5)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 for i in range(0, 5):
# ----> 2     plt.imshow(gt[i,1, :, :], cmap='jet')
#       3     plt.colorbar(shrink=0.5)
#       4     plt.show()
#
# IndexError: too many indices for array: array is 3-dimensional, but 4 were indexed

# %%
gt = np.load("/home/vatsal/NWM/Pangu/Pangu-Weather/input_data/input_upper.npy")

# %%
for i in range(0, 5):
    plt.imshow(prediction[i,1, :, :], cmap='jet')
    plt.colorbar(shrink=0.5)
    plt.show()

# %%
prediction.shape
# Out:
# (5, 13, 721, 1440)
